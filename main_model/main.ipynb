# %% [markdown]
# # Import Dependencies

# %%
import os
import json

# %% [markdown]
# # Directories

# %%
pheme_dir = 'data/pheme-rnr-dataset'

# %% [markdown]
# # Import the datasets

# %%
import os
import pandas as pd

# List to store the data
data = []

# Iterate over the events
for event_folder in os.listdir(pheme_dir):
    event_path = os.path.join(pheme_dir, event_folder)
    if os.path.isdir(event_path):
        # Check if the event folder contains both 'rumours' and 'non-rumours' subfolders
        rumours_path = os.path.join(event_path, 'rumours')
        non_rumours_path = os.path.join(event_path, 'non-rumours')
        if os.path.exists(rumours_path) and os.path.exists(non_rumours_path):
            # Load rumors
            rumours = os.listdir(rumours_path)
            for tweet_id in rumours:
                tweet_path = os.path.join(rumours_path, tweet_id, 'source-tweet')
                tweet_text = None
                for file_name in os.listdir(tweet_path):
                    if file_name.endswith('.json'):
                        with open(os.path.join(tweet_path, file_name), 'r', encoding='utf-8') as file:
                            tweet_data = json.load(file)
                            tweet_text = tweet_data['text']
                            break
                if tweet_text:
                    data.append({'Event': event_folder, 'Tweet ID': tweet_id, 'Label': 'rumor', 'Tweet Text': tweet_text})
            # Load non-rumours
            non_rumours = os.listdir(non_rumours_path)
            for tweet_id in non_rumours:
                tweet_path = os.path.join(non_rumours_path, tweet_id, 'source-tweet')
                tweet_text = None
                for file_name in os.listdir(tweet_path):
                    if file_name.endswith('.json'):
                        with open(os.path.join(tweet_path, file_name), 'r', encoding='utf-8') as file:
                            tweet_data = json.load(file)
                            tweet_text = tweet_data['text']
                            break
                if tweet_text:
                    data.append({'Event': event_folder, 'Tweet ID': tweet_id, 'Label': 'non-rumor', 'Tweet Text': tweet_text})

# Create a DataFrame from the collected data
pheme_df = pd.DataFrame(data)
print(pheme_df.head())
# Out:
#           Event            Tweet ID  Label  \
# 0  charliehebdo  552783238415265792  rumor
# 1  charliehebdo  552783667052167168  rumor
# 2  charliehebdo  552783745565347840  rumor
# 3  charliehebdo  552784168849907712  rumor
# 4  charliehebdo  552784526955806720  rumor
#
#                                           Tweet Text
# 0  Breaking: At least 10 dead, 5 injured after tO...
# 1  France: 10 people dead after shooting at HQ of...
# 2  Ten killed in shooting at headquarters of Fren...
# 3  BREAKING: 10 dead in shooting at headquarters ...
# 4  Reuters: 10 people shot dead at headquarters o...

# %% [markdown]
# # Data Cleaning

# %%
from main_model.scripts.data_cleaning import clean_text

# Assuming you have a DataFrame 'df' with a column 'Tweet Text'
pheme_df['Cleaned Text'] = pheme_df['Tweet Text'].apply(clean_text)

print(pheme_df.head())
# Out:
#           Event            Tweet ID  Label  \
# 0  charliehebdo  552783238415265792  rumor
# 1  charliehebdo  552783667052167168  rumor
# 2  charliehebdo  552783745565347840  rumor
# 3  charliehebdo  552784168849907712  rumor
# 4  charliehebdo  552784526955806720  rumor
#
#                                           Tweet Text  \
# 0  Breaking: At least 10 dead, 5 injured after tO...
# 1  France: 10 people dead after shooting at HQ of...
# 2  Ten killed in shooting at headquarters of Fren...
# 3  BREAKING: 10 dead in shooting at headquarters ...
# 4  Reuters: 10 people shot dead at headquarters o...
#
#                                         Cleaned Text
# 0  breaking at least  dead  injured after to gunm...
# 1  france  people dead after shooting at hq of sa...
# 2  ten killed in shooting at headquarters of fren...
# 3  breaking  dead in shooting at headquarters of ...
# 4  reuters  people shot dead at headquarters of f...

# %% [markdown]
# # POS Tagging

# %%
from sklearn.model_selection import train_test_split
import nltk

# Define a function to tag the text
def tag_text(text):
    words = nltk.word_tokenize(text)
    tagged_words = nltk.pos_tag(words)
    return tagged_words

pheme_df['POS Tagged Text'] = pheme_df['Cleaned Text'].apply(tag_text)

# Split the dataset into training, validation, and test sets
train_df, temp_df = train_test_split(pheme_df, test_size=0.4, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# Prepare the training data
train_data = []
for tagged_text in train_df['POS Tagged Text']:
    train_data.append(tagged_text)

# Prepare the validation data
val_data = []
for tagged_text in val_df['POS Tagged Text']:
    val_data.append(tagged_text)

# %%
print(train_data)
# Out:
# [[('let', 'VB'), ('there', 'EX'), ('be', 'VB'), ('more', 'JJR'), ('not', 'RB'), ('less', 'RBR'), ('charliehebdo', 'JJ')], [('google', 'NN'), ('is', 'VBZ'), ('donating', 'VBG'), ('nearly', 'RB'), ('to', 'TO'), ('charlie', 'VB'), ('hebdo', 'NN')], [('gun', 'NN'), ('fire', 'NN'), ('exchange', 'NN'), ('in', 'IN'), ('parliament', 'NN'), ('hill', 'NN'), ('building', 'VBG'), ('ottawa', 'PRP'), ('parliament', 'JJ'), ('shooting', 'VBG'), ('canada', 'JJ'), ('besafeottawa', 'NN'), ('via', 'IN'), ('martinvass', 'NN')], [('breaking', 'VBG'), ('gunman', 'NN'), ('in', 'IN'), ('sydneysiege', 'NN'), ('has', 'VBZ'), ('told', 'VBN'), ('police', 'NN'), ('he', 'PRP'), ('has', 'VBZ'), ('devices', 'NNS'), ('all', 'DT'), ('over', 'IN'), ('the', 'DT'), ('city', 'NN'), ('amp', 'NN'), ('demands', 'NNS'), ('to', 'TO'), ('speak', 'VB'), ('with', 'IN'), ('prime', 'JJ'), ('minister', 'NN'), ('acc', 'NN'), ('to', 'TO'), ('reports', 'NNS')], [('family', 'NN'), ('members', 'NNS'), ('of', 'IN'), ('victims', 'NNS'), ('of', 'IN'), ('germanwings', 'NNS'), ('crash', 'JJ'), ('arrive', 'VBP'), ('at', 'IN'), ('barcelonas', 'NNS'), ('el', 'VBP'), ('prat', 'NN'), ('airport', 'NN')], [('protestors', 'NNS'), ('outside', 'IN'), ('ferguson', 'JJ'), ('police', 'NN'), ('department', 'NN'), ('headquarters', 'NN'), ('right', 'RB'), ('now', 'RB')], [('ten', 'NNS'), ('dead', 'VBP'), ('in', 'IN'), ('shooting', 'VBG'), ('at', 'IN'), ('paris', 'JJ'), ('offices', 'NNS'), ('of', 'IN'), ('satirical', 'JJ'), ('magazine', 'NN'), ('charlie', 'NN'), ('hebdo', 'NN'), ('live', 'VBP'), ('updates', 'NNS')], [('i', 'NNS'), ('wake', 'VBP'), ('up', 'RP'), ('to', 'TO'), ('naacpbombing', 'NN'), ('and', 'CC'), ('charliehebdo', 'NN'), ('massacre', 'NN'), ('the', 'DT'), ('violence', 'NN'), ('of', 'IN'), ('both', 'DT'), ('betraying', 'VBG'), ('the', 'DT'), ('insecurity', 'NN'), ('amp', 'VBZ'), ('weakness', 'NN'), ('of', 'IN'), ('the', 'DT'), ('assailants', 'NNS')], [('arrest', 'NN'), ('being', 'VBG'), ('made', 'VBN'), ('chambers', 'NNS'), ('and', 'CC'), ('w', 'NN'), ('florissant', 'JJ'), ('right', 'NN'), ('now', 'RB'), ('ferguson', 'VBP')], [('my', 'PRP$'), ('deepest', 'JJS'), ('condolences', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('families', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('victims', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('flight', 'NN'), ('that', 'WDT'), ('crashed', 'VBD'), ('in', 'IN'), ('france', 'NN'), ('this', 'DT'), ('morning', 'NN'), ('germanwings', 'NNS')], [('i', 'NN'), ('dont', 'VBP'), ('feel', 'NN'), ('as', 'IN'), ('though', 'IN'), ('im', 'NN'), ('killing', 'VBG'), ('someone', 'NN'), ('with', 'IN'), ('a', 'DT'), ('pen', 'JJ'), ('stephane', 'NN'), ('charbonnier', 'NN'), ('charliehebdo', 'NN')], [('shorter', 'JJR'), ('ferguson', 'NN'), ('pd', 'NN'), ('damn', 'NN'), ('we', 'PRP'), ('thought', 'VBD'), ('we', 'PRP'), ('could', 'MD'), ('dirty', 'VB'), ('up', 'RP'), ('this', 'DT'), ('guys', 'NNS'), ('name', 'NN'), ('we', 'PRP'), ('didnt', 'VBP'), ('think', 'VB'), ('you', 'PRP'), ('guys', 'NNS'), ('would', 'MD'), ('check', 'VB')], [('mound', 'NN'), ('city', 'NN'), ('bar', 'NN'), ('association', 'NN'), ('has', 'VBZ'), ('agreed', 'VBN'), ('to', 'TO'), ('donate', 'VB'), ('their', 'PRP$'), ('time', 'NN'), ('pro', 'FW'), ('bono', 'FW'), ('for', 'IN'), ('any', 'DT'), ('witnesses', 'NNS'), ('that', 'WDT'), ('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('come', 'VB'), ('forward', 'RB'), ('ferguson', 'JJ'), ('mikebrown', 'NN')], [('charliehebdo', 'JJ'), ('gunmen', 'NNS'), ('fled', 'VBD'), ('in', 'IN'), ('stolen', 'NN'), ('car', 'NN'), ('after', 'IN'), ('mass', 'NN'), ('shootout', 'NN'), ('with', 'IN'), ('police', 'NN'), ('officers', 'NNS')], [('we', 'PRP'), ('are', 'VBP'), ('observing', 'VBG'), ('a', 'DT'), ('minutes', 'NNS'), ('silence', 'NN'), ('today', 'NN'), ('at', 'IN'), ('am', 'VBP'), ('if', 'IN'), ('you', 'PRP'), ('support', 'VBP'), ('press', 'NN'), ('freedom', 'NN'), ('please', 'NN'), ('share', 'NN'), ('amp', 'VBZ'), ('join', 'VB'), ('us', 'PRP'), ('jesuischarlie', 'VB')], [('too', 'RB'), ('man ...

# %%
print(val_data)
# Out:
# [[('horrible', 'JJ'), ('tragedy', 'NN'), ('in', 'IN'), ('paris', 'NN'), ('today', 'NN'), ('was', 'VBD'), ('not', 'RB'), ('done', 'VBN'), ('by', 'IN'), ('muslims', 'NNS'), ('but', 'CC'), ('done', 'VBN'), ('by', 'IN'), ('terrorists', 'NNS'), ('let', 'VBP'), ('us', 'PRP'), ('unite', 'VB'), ('against', 'IN'), ('hate', 'NN'), ('pray', 'NN'), ('for', 'IN'), ('peace', 'NN'), ('charliehebdo', 'NN')], [('pm', 'NN'), ('stephen', 'VBZ'), ('harper', 'JJR'), ('to', 'TO'), ('address', 'VB'), ('the', 'DT'), ('nation', 'NN'), ('on', 'IN'), ('ottawashooting', 'VBG'), ('at', 'IN'), ('pmet', 'JJ'), ('pmharper', 'NN'), ('cdnpoli', 'NN')], [('there', 'EX'), ('will', 'MD'), ('be', 'VB'), ('no', 'DT'), ('blackout', 'NN'), ('or', 'CC'), ('censoring', 'VBG'), ('the', 'DT'), ('global', 'JJ'), ('community', 'NN'), ('from', 'IN'), ('witnessing', 'VBG'), ('this', 'DT'), ('human', 'JJ'), ('travesty', 'JJ'), ('unity', 'NN'), ('ferguson', 'NN')], [('to', 'TO'), ('people', 'NNS'), ('taking', 'VBG'), ('selfies', 'NNS'), ('at', 'IN'), ('sydneysiege', 'NN'), ('when', 'WRB'), ('you', 'PRP'), ('return', 'VBP'), ('home', 'JJ'), ('look', 'NN'), ('at', 'IN'), ('your', 'PRP$'), ('selfie', 'NN'), ('amp', 'NN'), ('see', 'VBP'), ('what', 'WP'), ('an', 'DT'), ('unconscious', 'JJ'), ('blithering', 'NN'), ('idiot', 'JJ'), ('looks', 'NNS'), ('like', 'IN')], [('developing', 'VBG'), ('shooting', 'VBG'), ('suspect', 'NN'), ('at', 'IN'), ('large', 'JJ'), ('inside', 'JJ'), ('canadian', 'JJ'), ('parliament', 'NN'), ('reports', 'NNS')], [('parisbased', 'VBN'), ('journalist', 'NN'), ('says', 'VBZ'), ('the', 'DT'), ('attack', 'NN'), ('on', 'IN'), ('charlie', 'NN'), ('hebdos', 'NN'), ('hq', 'NN'), ('involved', 'VBN'), ('men', 'NNS'), ('armed', 'VBN'), ('with', 'IN'), ('rocket', 'NN'), ('propelled', 'VBD'), ('grenades', 'NNS')], [('along', 'IN'), ('with', 'IN'), ('all', 'DT'), ('our', 'PRP$'), ('fellow', 'NN'), ('canadians', 'VBZ'), ('our', 'PRP$'), ('thoughts', 'NNS'), ('are', 'VBP'), ('with', 'IN'), ('the', 'DT'), ('family', 'NN'), ('of', 'IN'), ('the', 'DT'), ('canadianforces', 'NNS'), ('member', 'NN'), ('killed', 'VBN'), ('today', 'NN'), ('ottawashooting', 'VBG')], [('sorry', 'NN'), ('tweeting', 'VBG'), ('jesuischarlie', 'NNS'), ('doesnt', 'RB'), ('cut', 'VBD'), ('it', 'PRP'), ('that', 'IN'), ('doesnt', 'VBZ'), ('defy', 'JJ'), ('islamism', 'NN'), ('its', 'PRP$'), ('pretend', 'NN'), ('courage', 'NN'), ('publish', 'VBD'), ('the', 'DT'), ('cartoons', 'NNS')], [('indian', 'JJ'), ('artist', 'NN'), ('sudarsan', 'JJ'), ('pattnaik', 'NN'), ('and', 'CC'), ('his', 'PRP$'), ('tribute', 'NN'), ('to', 'TO'), ('those', 'DT'), ('killed', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('attack', 'NN'), ('on', 'IN'), ('charlie', 'NN'), ('hebdo', 'NN')], [('my', 'PRP$'), ('wish', 'NN'), ('is', 'VBZ'), ('that', 'IN'), ('this', 'DT'), ('hostage', 'NN'), ('situation', 'NN'), ('in', 'IN'), ('sydney', 'NN'), ('ends', 'NNS'), ('without', 'IN'), ('anyone', 'NN'), ('getting', 'VBG'), ('hurt', 'NN')], [('charlie', 'NN'), ('hebdo', 'NN'), ('suspects', 'NNS'), ('and', 'CC'), ('police', 'NNS'), ('are', 'VBP'), ('said', 'VBD'), ('to', 'TO'), ('exchange', 'VB'), ('fire', 'NN'), ('northeast', 'NN'), ('of', 'IN'), ('paris', 'NN')], [('they', 'PRP'), ('should', 'MD'), ('stop', 'VB'), ('making', 'VBG'), ('attacks', 'NNS'), ('they', 'PRP'), ('are', 'VBP'), ('giving', 'VBG'), ('a', 'DT'), ('bad', 'JJ'), ('image', 'NN'), ('to', 'TO'), ('islam', 'VB'), ('charliehebdo', 'NN')], [('we', 'PRP'), ('are', 'VBP'), ('being', 'VBG'), ('forced', 'VBN'), ('to', 'TO'), ('leave', 'VB'), ('with', 'IN'), ('guns', 'NNS'), ('to', 'TO'), ('our', 'PRP$'), ('face', 'NN'), ('ferguson', 'NN')], [('uneasy', 'JJ'), ('night', 'NN'), ('st', 'NN'), ('louis', 'VBZ'), ('post', 'NN'), ('dispatchs', 'NN'), ('reporting', 'NN'), ('on', 'IN'), ('last', 'JJ'), ('nights', 'NNS'), ('clashes', 'NNS'), ('in', 'IN'), ('ferguson', 'NN')], [('ferguson', 'JJ'), ('officer', 'NN'), ('darren', 'NN'), ('wilson', 'NN'), ('will', 'MD'), ('be', 'VB'), ('lauded', 'VBN'), ('as', ' ...

# %%
from main_model.scripts.pos_tagging import pos_tagging

# Assuming 'train_data' and 'val_df' are defined elsewhere
best_tagger_name, best_tagger, best_tagger_accuracy = pos_tagging(train_data, val_df)

print("\nBest Tagger:", best_tagger_name)
print("Accuracy:", best_tagger_accuracy)
# Out:
# Unigram Tagger Accuracy: 0.8367168867430632
# Bigram Tagger Accuracy: 0.8597521959164679
# Trigram Tagger Accuracy: 0.8580652667093246
# HMM Tagger Accuracy: 0.8459077424233611
#
# Best Tagger: Bigram
# Accuracy: 0.8597521959164679

# %%
from nltk import word_tokenize

# Assuming 'best_tagger' is the best tagger selected
tagged_tweets = []
for tweet_text in pheme_df['Tweet Text']:
    tagged_tweet = best_tagger.tag(word_tokenize(tweet_text))
    tagged_tweets.append(tagged_tweet)

pheme_df['POS Tagged Text'] = tagged_tweets

# %%
print(pheme_df)
# Out:
#              Event            Tweet ID      Label  \
# 0     charliehebdo  552783238415265792      rumor
# 1     charliehebdo  552783667052167168      rumor
# 2     charliehebdo  552783745565347840      rumor
# 3     charliehebdo  552784168849907712      rumor
# 4     charliehebdo  552784526955806720      rumor
# ...            ...                 ...        ...
# 5797   sydneysiege  544521260840267776  non-rumor
# 5798   sydneysiege  544521433473634304  non-rumor
# 5799   sydneysiege  544521788777304064  non-rumor
# 5800   sydneysiege  544521880661950464  non-rumor
# 5801   sydneysiege  544521948924248066  non-rumor
#
#                                              Tweet Text  \
# 0     Breaking: At least 10 dead, 5 injured after tO...
# 1     France: 10 people dead after shooting at HQ of...
# 2     Ten killed in shooting at headquarters of Fren...
# 3     BREAKING: 10 dead in shooting at headquarters ...
# 4     Reuters: 10 people shot dead at headquarters o...
# ...                                                 ...
# 5797  Sydney siege ends as police storm Lindt Cafe a...
# 5798  Breaking News: #SydneySiege is over, according...
# 5799  Watch gunfire erupt and hostages flee chocolat...
# 5800  Authorities have confirmed that #sydneysiege i...
# 5801  WATCH: The dramatic moment tactical teams stor...
#
#                                            Cleaned Text  \
# 0     breaking at least  dead  injured after to gunm...
# 1     france  people dead after shooting at hq of sa...
# 2     ten killed in shooting at headquarters of fren...
# 3     breaking  dead in shooting at headquarters of ...
# 4     reuters  people shot dead at headquarters of f...
# ...                                                 ...
# 5797  sydney siege ends as police storm lindt cafe a...
# 5798  breaking news sydneysiege is over according to...
# 5799  watch gunfire erupt and hostages flee chocolat...
# 5800  authorities have confirmed that sydneysiege is...
# 5801  watch the dramatic moment tactical teams storm...
#
#                                         POS Tagged Text
# 0     [(Breaking, NN), (:, NN), (At, NN), (least, JJ...
# 1     [(France, NN), (:, NN), (10, NN), (people, NNS...
# 2     [(Ten, NN), (killed, VBN), (in, IN), (shooting...
# 3     [(BREAKING, NN), (:, NN), (10, NN), (dead, JJ)...
# 4     [(Reuters, NN), (:, NN), (10, NN), (people, NN...
# ...                                                 ...
# 5797  [(Sydney, NN), (siege, NN), (ends, VBZ), (as, ...
# 5798  [(Breaking, NN), (News, NN), (:, NN), (#, NN),...
# 5799  [(Watch, NN), (gunfire, NN), (erupt, VBP), (an...
# 5800  [(Authorities, NN), (have, VBP), (confirmed, V...
# 5801  [(WATCH, NN), (:, NN), (The, NN), (dramatic, J...
#
# [5802 rows x 6 columns]

# %% [markdown]
# # Lemmatization
